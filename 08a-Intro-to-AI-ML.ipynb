# %% [markdown]
# # Intro to Machine Learning
# We're going to be working with CAP imagery for the second half of this week. Recall the two main guiding questions for this week:
# - _What_ is in an image (e.g. debris, buildings, etc.)?
# - _Where_ are these things located _in 3D space_ ?
#
# ## Motivation
#
# We've already seen how structure from motion can begin to answer the second of those questions, at least in a coarse manner. The first question is more difficult than the second for one crucial reason: it (so far) can not be answered *solely* using image data. Recall that structure from motion was able to leverage image metadata, features and geometric constraints without having to insert any "outside" data. When detecting the components of an image, there is a certain amount of subjectivity that so far requires human input. For example, if you want to detect flooding in an image, there need to be some set of rules that the software can determine "if (rules are satisfied), then (flooding = True)".
#
# How can you start to tackle this problem? We're going to make the problem a bit simpler by turning it into a classification problem rather than a localization problem. That is, instead of finding where flooding is in an image, we'll find whether there is flooding at all. With that in mind, let's first try a naive approach and see if we can simply enumerate the rules. Let's look at some flooding images:
#
# <img src="notebook_images/010_1282_99809b0c-fc64-46e5-957f-7ff8e7547d8c.jpg" width="500"  />
#
# <img src="notebook_images/DSC_0655_0cbbe7e5-be24-4274-bf5a-664c6f2dc3e1.jpg" width="500"  />
#
# So what do we see? It looks like flooding is this murky, brown color that covers most of the image. So let's make a rule: if some percentage of the image is this brownish color (you can think of detecting this by creating some sort of index, like you did with the satellite imagery), there is flooding in the image. This might work for the two images we saw, but the real test is seeing if it works with other images. So let's look at another one:
#
# <img src="notebook_images/DSC_8218_7bb15c80-481b-411a-a54a-a36e9d8b6098.jpg" width="500"  />
#
# This image has a large percentage of it covered by brownish looking water. However, it's clearly not flooding, but rather just a lake. No problem, let's just make another rule: if some percentage of the image is this brownish color *and* there are also lots of buildings (let's also make an index for that), there is flooding in the image. Let's see if this works:
#
# <img src="notebook_images/DSC_8192_fe6812cd-c985-4e59-a62c-04a883ec42cc.jpg" width="500"  />
#
# Again, this is just some lake (the same lake as before, in fact). At this point, we might be thinking of shifting our strategy a bit. Clearly having someone sit down and enumerate all of the rules is impractical in this case\*. There is simply too much variability in the images to come up with a set of rules that is remotely generalizable.
#
# This is one of the major motivations of machine learning. The idea is that, rather than enumerate the rules that determine flooding, we're going to just enumerate the outcomes (e.g. whether there is flooding or not) and develop algorithms for the computer to *learn* what the rules are. There is a rich literature (and a host of undergraduate and graduate courses) on how these algorithms are designed, but on these next couple of days we will instead focus on how to interpret and implement them.
#
# \* This isn't to say that enumerating the rules isn't practical in *every* case. It really depends on the characteristics of the data.

# %% [markdown]
# ## A simple case study
#
# We're going to start with a simple dataset. We will use the  Breast Cancer Wisconsin (Diagnostic) Data Set (https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+(Diagnostic)), a dataset that shows whether a tumor is benign or malign and various other features.

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.datasets import load_breast_cancer
import re # regular expressions, part of standard python library

# read the dataframe
df = load_breast_cancer(return_X_y=False, as_frame=True)["data"]
df["target"] = load_breast_cancer(return_X_y=False, as_frame=True)["target"] # benign is 1, malign is 0
df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness
# 0          17.99         10.38          122.80     1001.0          0.11840  \
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry
# 0             0.27760         0.30010              0.14710         0.2419  \
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst texture  worst perimeter  worst area
# 0                   0.07871  ...          17.33           184.60      2019.0  \
# 1                   0.05667  ...          23.41           158.80      1956.0
# 2                   0.05999  ...          25.53           152.50      1709.0
# 3                   0.09744  ...          26.50            98.87       567.7
# 4                   0.05883  ...          16.67           152.20      1575.0
# ..                      ...  ...            ...              ...         ...
# 564                 0.05623  ...          26.40           166.10      2027.0
# 565                 0.05533  ...          38.25           155.00      1731.0
# 566                 0.05648  ...          34.12           126.70      1124.0
# 567                 0.07016  ...          39.42           184.60      1821.0
# 568                 0.05884  ...          30.37            59.16       268.6
#
#      worst smoothness  worst compactness  worst concavity
# 0             0.16220            0.66560           0.7119  \
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      worst concave points  worst symmetry  worst fractal dimension  target
# 0                  0.2654          0.4601                  0.11890       0
# 1                  0.1860          0.2750                  0.08902       0
# 2                  0.2430          0.3613                  0.08758       0
# 3                  0.2575          0.6638                  0.17300       0
# 4                  0.1625          0.2364                  0.07678       0
# ..                    ...             ...                      ...     ...
# 564                0.2216          0.2060                  0.07115       0
# 565                0.1628          0.2572                  0.06637       0
# 566                0.1418          0.2218                  0.07820       0
# 567                0.2650          0.4087                  0.12400       0
# 568                0.0000          0.2871                  0.07039       1
#
# [569 rows x 31 columns]

# %%
# for now we're just going to focus on mean radius and mean texture.
# we'll plot one against the other, and color code depending on survival
df_b = df[df["target"] == 1]
df_m = df[df["target"] == 0]
#Benign - no canceroous tumor - 1 postive
#Maligmam - Cancerous tumors - 0 negative
# plotting
plt.plot(df_b["mean radius"], df_b["mean texture"], "ro")
plt.plot(df_m["mean radius"], df_m["mean texture"], "bo")
plt.xlabel("mean radius")
plt.ylabel("mean texture")
plt.show()

#Maligmam greaster texture & bigger
#Also more variation than Benign
#A bit of overlap

# %% [markdown]
# So what do we see? Clearly there are factors beyond the ones plotted that explain whether a tumor is benign. However, it's not difficult to see a pattern here. The further up and to the right you are, the less likely you are to survive. So as a first attempt, we will have the software learn a *linear classifier*. This classifier will be a line that will classify you as benign if you are below the line, and malign otherwise.

# %%
#Features : X, Target/Prediction: Y

#Training v.s. Testing Set:
# - Training: 80% of og data is apart of this set
# - Testing: 20%, Unseen Data to see how well your Algorithm is
#Do not want to overfit Algorithms to Datasets
#---------------------------------------------------------------------
#Support Vector Machine:
#Draws a line within dataset to classify data based on which side of the line it falls on
#Also called Decision Boundary
#Can be Linear (Straight) or Non-Linear (Squiggly)
#__________________________________________________________________

# %%
from sklearn import svm
from sklearn.model_selection import train_test_split
try:
    from mlxtend.plotting import plot_decision_regions
except:
    # !pip install mlxtend
    from mlxtend.plotting import plot_decision_regions

# setting the features and the targets
X = df[["mean radius", "mean texture"]]
y = df["target"]

# splitting training and testing set 80/20
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Initialize SVM classifier
classifier = svm.SVC(kernel='linear')

# Fit data
classifier = classifier.fit(X_train, y_train)

# Printing parameters
coef = classifier.coef_
print(coef)

# Plot decision boundary
plot_decision_regions(X_train.values, y_train.values.astype(np.integer), clf=classifier, legend=2)
plt.xlabel("mean radius")
plt.ylabel("mean texture")
plt.show()
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.23.1-py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 23.0 MB/s eta 0:00:00 0:00:01
# Requirement already satisfied: numpy>=1.16.2 in /opt/conda/lib/python3.10/site-packages (from mlxtend) (1.23.5)
# Requirement already satisfied: scikit-learn>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from mlxtend) (1.2.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from mlxtend) (3.7.1)
# Requirement already satisfied: joblib>=0.13.2 in /opt/conda/lib/python3.10/site-packages (from mlxtend) (1.2.0)
# Requirement already satisfied: pandas>=0.24.2 in /opt/conda/lib/python3.10/site-packages (from mlxtend) (2.0.0)
# Requirement already satisfied: scipy>=1.2.1 in /opt/conda/lib/python3.10/site-packages (from mlxtend) (1.10.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (4.39.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=1.0.2->mlxtend) (3.1.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.1
# [[-0.66511088 -0.13778709]]
# /tmp/ipykernel_94/2364271867.py:39: DeprecationWarning: Converting `np.integer` or `np.signedinteger` to a dtype is deprecated. The current result is `np.dtype(np.int_)` which is not strictly correct. Note that the result depends on the system. To ensure stable results use may want to use `np.int64` or `np.int32`.
#   plot_decision_regions(X_train.values, y_train.values.astype(np.integer), clf=classifier, legend=2)
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %% [markdown]
# There is a lot going on here, so let's try to break it down. Recall that we are trying to determine whether a patient survives using just the (normalized) age and detected nodes. These are called the explanatory variables or *features*, and we refer to it as $X$. The variable we are trying to predict is the prediction variable or *target*, and we refer to it as $y$.
#
# The underlying notion behind machine learning is that patterns that hold in a subset of data will hold in the population as a whole. So in a sense, we care about the performance of the classifier on data that the algorithm has *not* seen by learning patterns in that data that we have seen. To this end, one of the major paradigms in machine learning is to separate our data into a *training set* and a *testing set*. The training set is a subset of the given data that we will actually provide to the algorithm to learn, while the testing set will be used solely to report the performance on data that the algorithm has not seen. In our case, we set 80% of the data as training data and 20% as testing data.
#
# There are numerous algorithms that can train on data. One of the more popular ones (especially before neural networks were introduced) are called *support vector machines* (SVM). We will not discuss how it actually does the learning, but suffice to say it takes in the training data and finds the line that minimizes the classification error. This line is called the *decision boundary* and it is defined by the following equation:
#
# \begin{equation}
# C_1(mean\ radius) + C_2(mean\ texture) = 0
# \end{equation}
#
# Where $C_1$ and $C_2$ are the coefficients of the linear classifier. So really, the function of the SVM is to find these two coefficients. The algorithm then does classification as follows:
#
# \begin{equation}
# y_{pred} =
# \begin{cases}
#     1               & \text{if } C_1(mean\ radius) + C_2(mean\ texture)\geq 0\\
#     0,              & \text{otherwise}
# \end{cases}
# \end{equation}
#
# ### Exercise
# - Look at the first 5 samples in the testing data set. Calculate the predicted target of each of the 5 samples?
# - Look at the corresponding targets. Are the predictions accurate? What proportion of the predicted values are correctly predicted?
# - Which of the two coefficients is most important? Why?

# %%
accuracy = []
first5 = X_test[:5]
C1 = first5['mean radius']
C2 = first5['mean texture']
New= C1 + C2


for pred in New:
    New.index.get_loc(New[New['Name'] == 'David']
#     if pred >= 0:
#         New[index(pred)] = 0
# print(New) 
# y_test5 = y_test.head(5)
# print(New)
# for index, item in enumerate(y_test5):
#     compare = list(New)[index]
#     print(item)
#     print(compare)
# Out:
# 362    31.60
# 516    38.89
# 100    38.59
# 106    29.97
# 346    30.96
# dtype: float64

# %% [raw]
# How good is our classifier? We can look at the performance of our classifier on the testing set to find out. Of course, an important metric to look out for is the accuracy:
#
# \begin{equation}
# \text{Accuracy} = \frac{\#\ (y_{true} == y_{pred})}{\# \ \text{samples}}
# \end{equation}
#
# However, for most applications it is also worth understanding what your *false positive* and *false negative* rate is. A false positive is a sample that is classified as a 1 but is in reality a 0, and a false negative is the opposite\*. The false positive rate is defined as $\frac{\# \text{False positives}}{\# \ \text{False positives + True negatives}}$, while the false negative rate is defined as $\frac{\# \text{False negatives}}{\# \ \text{False negatives + True positives}}$. **Why would this be a metric we care about, especially in this case?**
#
# <details>
#     <summary>ANSWER</summary>
#     Imagine your tumor is predicted as malignant but is in fact benign. There is certainly now a cost you incur in further tests or surgeries, but ultimately it is a manageable cost. Now imagine if you predicted a tumor as benign even thoguh it is malignant. Here, the mistake of the classifier could certainly cost you your life.
# </details>
#
# It turns out there is a useful tool called a *confusion matrix* that handily lays it out for you.
#
# \* It's worth putting some effort into what we call positives and negatives. Here, we use the term positive to mean 1 (benign) and negative to mean 0 (malign). However, anyone that has had a test of any sort knows that positive usually means that you have the disease (in our case, malign tumor). A lot of data science is communicating results, so something worth thinking about.

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

predictions = classifier.predict(X_test)
accuracy = np.sum(predictions == y_test)/np.size(predictions)
print(accuracy)

cm = confusion_matrix(y_test, predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=['malignant', 'benign'])

disp.plot()
plt.show()

#
# Out:
# 0.8859649122807017

# %% [markdown]
# As a final note, we used two variables (radius and texture) because it made it possible to visualize. However, there is nothing preventing us from using the rest of the data set columns as part of our features. While visualization in more than 2D is much more difficult, the underlying principles are exactly the same.

# %% [markdown]
# ![nn_deep.png](attachment:03c688bf-3135-4c0f-9e68-6e1b33d8a2b8.png)## Deep learning
# So far, we've worked exclusively with linear decision boundaries. However, usually data is much more complicated (as you should have seen from the exercise). Therefore, we might want to look for something that has higher predictive power. One of the most popular tools in machine learning has been the *neural network*. A neural network is (loosely) inspired by the way neurons are connected and operate. Let's first look at the simplest possible neural network and work our way up:
#
# <img src="notebook_images/nn_nohidden_new.png" width="500"  />
#
# Neural networks are made up of *layers*. In the image above, the neural network has two layers. The first layer is called the *input layer*, and the last layer is called the *output layer*. Each layer is composed of *neurons*. In the input layer, each neuron is one of the features from the training data. For example, the first neuron might be the mean radius, and the second neuron might be the mean texture. We're going to refer to each neuron by $x_{l, n}$, where $l$ is the number of the layer and $n$ is the number of the neuron within the layer. Using this notation, mean radius = $x_{1, 1}$.
#
# Each neuron in the input layer is connected to *every* neuron in the following layer by a *weight*. We will denote each weight by $w_{l, i, o}$, where $l$ is the layer at the tail of the arrow, $i$ is the number of the neuron at the tail of the arrow and $o$ is the number of the neuron at the head of the arrow. In the figure above, the color of the arrow corresponds to the value of the weight (blue means negative, red means positive). Every neuron in subsequent layers is equal to the sum of the products of the neurons and the weight that connects them. In this case, the neuron in the output layer is defined as:
#
# \begin{equation}
# x_{2, 1} = x_{1, 1}w_{1, 1, 1} + x_{1, 2}w_{1, 2, 1}
# \end{equation}
#
# Once you have the value of the output layer, you can obtain the predicted classification by applying some function to $x_{2, 1}$. An example of such a function would be similar to what we did previously:
#
# \begin{equation}
# y_{pred} =
# \begin{cases}
#     1               & \text{if } x_{2, 1}\geq 0\\
#     0,              & \text{otherwise}
# \end{cases}
# \end{equation}
#
# So training a neural network is simply finding the weights $w$ that minimize the error. If you are keen-eyed though, you might have realized that the example above is identical to what we were doing before. Therefore, we still have not arrived at a more powerful classifier. Let's try a more complicated neural network.
#
# <img src="notebook_images/nn_hidden_new.png" width="500"  />
#
# This network is similar to the previous one, but now we have an additional layer in between the input and output layers. All layers that are between input and output are called *hidden layers*, though functionally they behave in exactly the same way. As a quick concept question, **what is the value of $x_{2, 3}$? What about $x_{3, 1}$?**
#
# <details>
#     <summary>ANSWER</summary>
#     $x_{2, 3} = x_{1, 1}w_{1, 1, 3} + x_{1, 2}w_{1, 2, 3}$ ,
#     $x_{3, 1} = x_{2, 1}w_{2, 1, 1} + x_{2, 2}w_{2, 2, 1} + x_{2, 3}w_{2, 3, 1} + x_{2, 4}w_{2, 4, 1} + x_{2, 5}w_{2, 5, 1}$
# </details>
#
# Why are we introducing a hidden layer? Notice that each of the neurons in the hidden layer are essentially acting as linear classifiers. By having a weighted sum of these neurons in the output layer, we are arriving at a function that, by virtue of being a sum of lines is not itself linear. One of the biggest results in machine learning is that, as you increase the number of neurons in the hidden layer, you can approximate *any* function, meaning that you can always make a more powerful classifier by just adding more neurons. However, usually this is not computationally efficient. Rather, most of the time it makes more sense to introduce more hidden layers as opposed to more neurons, as shown in the image below:
#
# <img src="notebook_images/nn_deep.png" width="500"  />
#
# The added "depth" as a result of more layers is where the "deep" in "deep learning" comes. As computational resources have increased, scientists have increasingly resorted to adding more and more layers to their neural networks.
#
# ### Discussion questions
# Let's start thinking about the LADI dataset. We want to use deep learning to detect whether there is flooding in the image.
# - Using the paradigm above, what would be the features of the dataset? What are the targets?
# - Propose a way that you would input the features into a neural network?
# - What problems might you run into if you directly put an image into the neural network above?

# %% [markdown]
# ## Convolution
# Convolution is a fairly old technique in image processing. Convolution works by multiplying a matrix (called a *kernel*) with portions of the image and adding up the result. An animation of how this works is shown below. The result of applying different kernels is also shown:
#
# <img src="notebook_images/convolution_anim.gif" width="500"  />
#
# <img src="notebook_images/convolution.png" width="500"  />
#
# As you can see, different kernels can pick up different features depending on the specific coefficients of the kernel. In the late 1980s, scientists first thought to use neural networks to learn the kernel values themselves, which created the foundation for the *convolutional* neural network (CNN). These complement the hidden layers from the previous architecture with new convolutional layers, which perform convolution on the previous layer. In so doing, these networks conserve the relationship between nearby pixels and perform very well in image classification.
#
# <img src="notebook_images/cnn.png" width="500"  />

# %% [markdown]
# ## The LADI dataset
# The LADI dataset contains CAP images as well as crowdsourced labels for a number of different categories. Today we're going to start the multi-day exercise of applying deep learning to the LADI dataset in order to do classification of flooding. This section borrows heavily from the following tutorial: https://github.com/LADI-Dataset/ladi-tutorial
#
# ### Data reading and cleaning
# We first have to go through some work to make sure that we only have the components of the dataset that we want.

# %%
# read the tsv file with the labels
ladi_responses_raw = pd.read_csv("http://ladi.s3-us-west-2.amazonaws.com/Labels/ladi_aggregated_responses_url.tsv",delimiter='\t',header='infer')
ladi_responses_raw
# Out:
#                                                       url  WorkerId
# 0       https://ladi.s3-us-west-2.amazonaws.com/Images...         0  \
# 1       https://ladi.s3-us-west-2.amazonaws.com/Images...         1
# 2       https://ladi.s3-us-west-2.amazonaws.com/Images...         2
# 3       https://ladi.s3-us-west-2.amazonaws.com/Images...        20
# 4       https://ladi.s3-us-west-2.amazonaws.com/Images...         0
# ...                                                   ...       ...
# 289835  https://ladi.s3-us-west-2.amazonaws.com/Images...       488
# 289836  https://ladi.s3-us-west-2.amazonaws.com/Images...       496
# 289837  https://ladi.s3-us-west-2.amazonaws.com/Images...       516
# 289838  https://ladi.s3-us-west-2.amazonaws.com/Images...       539
# 289839  https://ladi.s3-us-west-2.amazonaws.com/Images...       539
#
#                         Answer
# 0       ['damage:flood/water']
# 1       ['damage:flood/water']
# 2       ['damage:flood/water']
# 3       ['damage:flood/water']
# 4       ['damage:flood/water']
# ...                        ...
# 289835         ['damage:none']
# 289836         ['damage:none']
# 289837         ['damage:misc']
# 289838         ['damage:none']
# 289839         ['damage:none']
#
# [289840 rows x 3 columns]

# %%
# remove square brackets, split on comma and explode list into individual rows, then merge back with original to get url and WorkerId
ladi_responses = pd.merge(ladi_responses_raw[['url','WorkerId']], 
                          ladi_responses_raw['Answer'].str.strip('[|]').str.split(',').explode(), 
                          left_index=True, 
                          right_index=True).reset_index(drop=True)
# remove whitespace and the single quote character from either end of string
ladi_responses['Answer'] = ladi_responses['Answer'].str.strip(' ').str.strip('\'')
# add a column to help with aggregation when pivoting
ladi_responses['response_count'] = 1
# get the category of each response
ladi_responses['Category'] = ladi_responses['Answer'].str.split(':').apply(lambda x: x[0])
# drop dupes
ladi_responses = ladi_responses.drop_duplicates(ignore_index=True)
ladi_responses
# Out:
#                                                       url  WorkerId
# 0       https://ladi.s3-us-west-2.amazonaws.com/Images...         0  \
# 1       https://ladi.s3-us-west-2.amazonaws.com/Images...         1
# 2       https://ladi.s3-us-west-2.amazonaws.com/Images...         2
# 3       https://ladi.s3-us-west-2.amazonaws.com/Images...        20
# 4       https://ladi.s3-us-west-2.amazonaws.com/Images...         0
# ...                                                   ...       ...
# 394697  https://ladi.s3-us-west-2.amazonaws.com/Images...       488
# 394698  https://ladi.s3-us-west-2.amazonaws.com/Images...       496
# 394699  https://ladi.s3-us-west-2.amazonaws.com/Images...       516
# 394700  https://ladi.s3-us-west-2.amazonaws.com/Images...       539
# 394701  https://ladi.s3-us-west-2.amazonaws.com/Images...       539
#
#                     Answer  response_count Category
# 0       damage:flood/water               1   damage
# 1       damage:flood/water               1   damage
# 2       damage:flood/water               1   damage
# 3       damage:flood/water               1   damage
# 4       damage:flood/water               1   damage
# ...                    ...             ...      ...
# 394697         damage:none               1   damage
# 394698         damage:none               1   damage
# 394699         damage:misc               1   damage
# 394700         damage:none               1   damage
# 394701         damage:none               1   damage
#
# [394702 rows x 5 columns]

# %%
#figure out the total number of responses in each category
# take one entry for each worker, category, url combination, and then create pivot table from it
category_matrix = ladi_responses.groupby(['WorkerId','Category','url'])\
                                .first()\
                                .reset_index()\
                                .pivot_table(values='response_count', 
                                          index='url', 
                                          columns='Category', 
                                          aggfunc='sum',
                                          fill_value=0)
category_matrix
# Out:
# Category                                            damage  environment
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...       6            0  \
# https://ladi.s3-us-west-2.amazonaws.com/Images/...       5            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...       3            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...       3            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...       3            3
# ...                                                    ...          ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...       6            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...       8            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...       3            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...       5            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...       6            0
#
# Category                                            infrastructure  vehicle
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0        0  \
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0        0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0        0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0        0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               3        3
# ...                                                            ...      ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0        0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0        0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0        0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0        0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0        0
#
# Category                                            water
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...      0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...      0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...      0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...      0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...      3
# ...                                                   ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...      0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...      0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...      0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...      0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...      0
#
# [40197 rows x 5 columns]

# %%
# Create a matrix with the number of workers who answered given label for given image
# using pivot table; filling in nan values with 0
label_matrix = ladi_responses.pivot_table(values='response_count', 
                                          index='url', 
                                          columns='Answer', 
                                          aggfunc='sum',
                                          fill_value=0)
label_matrix
# Out:
# Answer                                              damage:flood/water
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                   2  \
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                   3
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                   1
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                   2
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                   2
# ...                                                                ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                   3
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                   1
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                   0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                   1
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                   2
#
# Answer                                              damage:landslide
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0  \
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# ...                                                              ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 2
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 2
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 1
#
# Answer                                              damage:misc  damage:none
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0            4  \
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0            2
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0            2
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0            1
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0            1
# ...                                                         ...          ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            3            2
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            1            5
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            1            2
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            1            2
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            1            3
#
# Answer                                              damage:rubble
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0  \
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# ...                                                           ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              2
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              1
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              1
#
# Answer                                              damage:smoke/fire
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0  \
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# ...                                                               ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
#
# Answer                                              damage:washout
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0  \
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
# ...                                                            ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               1
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               1
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               1
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               1
#
# Answer                                              environment:dirt
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0  \
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# ...                                                              ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
#
# Answer                                              environment:grass
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0  \
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# ...                                                               ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
#
# Answer                                              environment:lava  ...
# url                                                                   ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0  ...  \
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0  ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0  ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0  ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0  ...
# ...                                                              ...  ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0  ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0  ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0  ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0  ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0  ...
#
# Answer                                              vehicle:boat  vehicle:car
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0            0  \
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0            3
# ...                                                          ...          ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0            0
#
# Answer                                              vehicle:none
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0  \
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0
# ...                                                          ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0
#
# Answer                                              vehicle:truck
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0  \
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              1
# ...                                                           ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
#
# Answer                                              water:flooding
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0  \
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               3
# ...                                                            ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
#
# Answer                                              water:lake  water:none
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...           0           0  \
# https://ladi.s3-us-west-2.amazonaws.com/Images/...           0           0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...           0           0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...           0           0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...           0           0
# ...                                                        ...         ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...           0           0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...           0           0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...           0           0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...           0           0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...           0           0
#
# Answer                                              water:ocean  water:puddle
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0             0  \
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0             0
# ...                                                         ...           ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0             0
#
# Answer                                              water:river
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0
# ...                                                         ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0
#
# [40197 rows x 37 columns]

# %%
# create dataframes with percentage of responses that included that label
cat_frac_dfs = {}
for cat in category_matrix.columns:
    frac_df = pd.DataFrame(index=category_matrix.index)
    for label in label_matrix.columns[label_matrix.columns.str.match(cat)]:
        frac_df[label] = (label_matrix[label]/category_matrix[cat])
    cat_frac_dfs[cat] = frac_df.fillna(0)

# %%
def get_training_examples(cat_frac_dfs, category, label, max_samples=5000):
    '''gets the files for a given category and label where the majority of workers said that the label was present
    use max_samples to limit the number of examples
    '''
    if re.search('none', label):
        sample_df = pd.DataFrame(index=cat_frac_dfs[category].loc[cat_frac_dfs[category][label]>0.5].index)
    else:
        sample_df = pd.DataFrame(index=cat_frac_dfs[category].loc[cat_frac_dfs[category][label]>=0.5].index, data={label:1})
    if len(sample_df) > max_samples:
        sample_df = sample_df.sample(max_samples)
    return sample_df

def convert_url_to_local_path(url):
    '''
    converts the url to the location where we will download
    '''
    return url.lstrip('https://')

# %%
# get positive examples for each label of interest
flood_examples = get_training_examples(cat_frac_dfs, 'damage', 'damage:flood/water', 100)
rubble_examples = get_training_examples(cat_frac_dfs, 'damage', 'damage:rubble', 100)
misc_damage_examples = get_training_examples(cat_frac_dfs, 'damage', 'damage:misc', 100)
no_damage_examples = get_training_examples(cat_frac_dfs, 'damage', 'damage:none', 100)

# %%
# combine entries entries into single dataframe, group by url, and convert labels to 1-hot vector
damage_df = pd.concat([flood_examples, 
                       rubble_examples,
                       misc_damage_examples,
                       no_damage_examples
                      ]).fillna(0).reset_index().groupby('url').max()
damage_df['local_path'] = damage_df.reset_index()['url'].apply(convert_url_to_local_path).values
damage_df.to_csv('damage_examples.csv')
damage_df
# Out:
#                                                     damage:flood/water
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 1.0  \
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 1.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 1.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 1.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0.0
# ...                                                                ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 1.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 1.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0.0
#
#                                                     damage:rubble
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0.0  \
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0.0
# ...                                                           ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0.0
#
#                                                     damage:misc
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...          0.0  \
# https://ladi.s3-us-west-2.amazonaws.com/Images/...          0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...          0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...          0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...          0.0
# ...                                                         ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...          0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...          0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...          0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...          0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...          0.0
#
#                                                                                            local_path
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...  ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CA...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...  ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CA...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...  ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CA...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...  ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CA...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...  ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CA...
# ...                                                                                               ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...  ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CA...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...  ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CA...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...  ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CA...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...  ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CA...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...  ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CA...
#
# [397 rows x 4 columns]

# %%
# create a csv of all the files we want to download as training data to feed into wget
damage_df.reset_index()['url'].to_csv('urls_to_download.csv', index=False, header=False)

# %%
# Load ladi_images_metadata.csv
metadata_df = pd.read_csv('http://ladi.s3-us-west-2.amazonaws.com/Labels/ladi_images_metadata.csv')
metadata_df
# Out:
#                                             uuid            timestamp
# 0       a13fb353cca1f5e8060f95c80deb0c49e9a21f91  2016-01-16 07:34:55  \
# 1       03e5da2bc5e32cd7d58a164eefce499e2f14e06f  2014-06-24 13:09:20
# 2       c97e83122e14ec5fa5cfa6e2c911e066d8a07f7c  2014-06-24 11:06:27
# 3       c534eb158948b63508eab34a667bf495e129f455  2014-06-24 11:20:03
# 4       1c702459e21e5a7e7fec5eefaab42f5e5124113a  2014-06-24 11:21:07
# ...                                          ...                  ...
# 580746  95fabbdbbb494beab517b5fea25a4e430d8fbcef  2020-01-27 12:01:31
# 580747  4b590e5634dae396db6c838844d7670e5ef9e7f6  2020-01-27 12:00:25
# 580748  bb7f86f1e9ab1a1ab3ea9e13cda998ab6e1bbb6d  2020-01-27 12:02:25
# 580749  c9e5c19cb7cccf181d11b707f1a47b80341710b6  2020-01-27 12:00:45
# 580750  a52da08206e51e3cd3b2cd0b42a3bb7e9623e92c  2020-01-27 12:00:39
#
#           gps_lat    gps_lon  gps_alt  file_size   width  height
# 0       29.623744 -95.652153     26.0  3497125.0  4608.0  3456.0  \
# 1       32.386939 -86.344467    489.0  3518243.0  4608.0  3456.0
# 2             NaN        NaN      NaN  8006650.0  6000.0  4000.0
# 3             NaN        NaN      NaN  8821238.0  6000.0  4000.0
# 4       32.371777 -86.345887    459.0  8385536.0  6000.0  4000.0
# ...           ...        ...      ...        ...     ...     ...
# 580746  18.002950 -66.896370    101.8  3413576.0  4000.0  3000.0
# 580747  18.003440 -66.896118    101.8  3307879.0  4000.0  3000.0
# 580748  18.003280 -66.895955    101.8  3989427.0  4000.0  3000.0
# 580749  18.003355 -66.896257    101.8  3722615.0  4000.0  3000.0
# 580750  18.003379 -66.896208    101.8  3696682.0  4000.0  3000.0
#
#                                                   s3_path
# 0       s3://ladi/Images/FEMA_CAP/1012/20118/VIRB0002_...  \
# 1       s3://ladi/Images/FEMA_CAP/1012/20118/VIRB0820_...
# 2       s3://ladi/Images/FEMA_CAP/1012/20118/_DSC0015_...
# 3       s3://ladi/Images/FEMA_CAP/1012/20118/_DSC0123_...
# 4       s3://ladi/Images/FEMA_CAP/1012/20118/_DSC0126_...
# ...                                                   ...
# 580746  s3://ladi/Images/FEMA_CAP/9173/616637/2020_012...
# 580747  s3://ladi/Images/FEMA_CAP/9173/616637/2020_012...
# 580748  s3://ladi/Images/FEMA_CAP/9173/616637/2020_012...
# 580749  s3://ladi/Images/FEMA_CAP/9173/616637/2020_012...
# 580750  s3://ladi/Images/FEMA_CAP/9173/616637/2020_012...
#
#                                                       url
# 0       https://ladi.s3-us-west-2.amazonaws.com/Images...
# 1       https://ladi.s3-us-west-2.amazonaws.com/Images...
# 2       https://ladi.s3-us-west-2.amazonaws.com/Images...
# 3       https://ladi.s3-us-west-2.amazonaws.com/Images...
# 4       https://ladi.s3-us-west-2.amazonaws.com/Images...
# ...                                                   ...
# 580746  https://ladi.s3-us-west-2.amazonaws.com/Images...
# 580747  https://ladi.s3-us-west-2.amazonaws.com/Images...
# 580748  https://ladi.s3-us-west-2.amazonaws.com/Images...
# 580749  https://ladi.s3-us-west-2.amazonaws.com/Images...
# 580750  https://ladi.s3-us-west-2.amazonaws.com/Images...
#
# [580751 rows x 10 columns]

# %%
#download the examples to folder
# !wget --content-disposition --trust-server-names -i urls_to_download.csv -x
# Out:
# --2024-07-29 15:58:24--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20150/DSC_0012_058051a0-26a8-436a-a23d-8b3e7cb60c3d.jpg
# Resolving ladi.s3-us-west-2.amazonaws.com (ladi.s3-us-west-2.amazonaws.com)... 52.218.182.17, 3.5.77.118, 52.92.185.42, ...
# Connecting to ladi.s3-us-west-2.amazonaws.com (ladi.s3-us-west-2.amazonaws.com)|52.218.182.17|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6383549 (6.1M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20150/DSC_0012_058051a0-26a8-436a-a23d-8b3e7cb60c3d.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.09M  --.-KB/s    in 0.1s
#
# 2024-07-29 15:58:25 (49.5 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20150/DSC_0012_058051a0-26a8-436a-a23d-8b3e7cb60c3d.jpg’ saved [6383549/6383549]
#
# --2024-07-29 15:58:25--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20195/DSC_0344_20e50e66-01c5-4e58-9c8d-727a48a4f317.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6386426 (6.1M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20195/DSC_0344_20e50e66-01c5-4e58-9c8d-727a48a4f317.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.09M  --.-KB/s    in 0.06s
#
# 2024-07-29 15:58:25 (102 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20195/DSC_0344_20e50e66-01c5-4e58-9c8d-727a48a4f317.jpg’ saved [6386426/6386426]
#
# --2024-07-29 15:58:25--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/2024/221180/010_2374_27cab62f-305c-43ef-a416-1a2b3f66f28f.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 11380597 (11M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/2024/221180/010_2374_27cab62f-305c-43ef-a416-1a2b3f66f28f.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  10.85M  58.1MB/s    in 0.2s
#
# 2024-07-29 15:58:25 (58.1 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/2024/221180/010_2374_27cab62f-305c-43ef-a416-1a2b3f66f28f.jpg’ saved [11380597/11380597]
#
# --2024-07-29 15:58:25--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/2024/221180/010_2469_ce8b6a16-7e73-4e05-addc-eaf99c60fa6d.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 12219092 (12M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/2024/221180/010_2469_ce8b6a16-7e73-4e05-addc-eaf99c60fa6d.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  11.65M  37.8MB/s    in 0.3s
#
# 2024-07-29 15:58:25 (37.8 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/2024/221180/010_2469_ce8b6a16-7e73-4e05-addc-eaf99c60fa6d.jpg’ saved [12219092/12219092]
#
# --2024-07-29 15:58:25--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/2032/200914/_DSC8000_909b7b0d-55fb-41e7-8804-044e59e9cee8.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 11361002 (11M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/2032/200914/_DSC8000_909b7b0d-55fb-41e7-8804-044e59e9cee8.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  10.83M  25.3MB/s    in 0.4s
#
# 2024-07-29 15:58:26 (25.3 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/2032/200914/_DSC8000_909b7b0d-55fb-41e7-8804-044e59e9cee8.jpg’ saved [11361002/11361002]
#
# --2024-07-29 15:58:26--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3041/241283/DSC_9361_2982a6d8-2f70-4af9-8a2e-60c2358a0ba3.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7371580 (7.0M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3041/241283/DSC_9361_2982a6d8-2f70-4af9-8a2e-60c2358a0ba3.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   7.03M  --.-KB/s    in 0.05s
#
# 2024-07-29 15:58:26 (133 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3041/241283/DSC_9361_2982a6d8-2f70-4af9-8a2e-60c2358a0ba3.jpg’ saved [7371580/7371580]
#
# --2024-07-29 15:58:26--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291491/StJohnRv_c3ec0309-e371-4230-a7ac-33031c1b59e7.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 10935171 (10M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291491/StJohnRv_c3ec0309-e371-4230-a7ac-33031c1b59e7.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  10.43M  22.6MB/s    in 0.5s
#
# 2024-07-29 15:58:27 (22.6 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291491/StJohnRv_c3ec0309-e371-4230-a7ac-33031c1b59e7.jpg’ saved [10935171/10935171]
#
# --2024-07-29 15:58:27--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291497/DSC_0382_1d82e733-512e-447c-b5af-177028e4dcca.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7068111 (6.7M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291497/DSC_0382_1d82e733-512e-447c-b5af-177028e4dcca.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.74M  --.-KB/s    in 0.08s
#
# 2024-07-29 15:58:27 (81.1 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291497/DSC_0382_1d82e733-512e-447c-b5af-177028e4dcca.jpg’ saved [7068111/7068111]
#
# --2024-07-29 15:58:27--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291497/DSC_0540_7e315ca6-a223-46c1-980a-5604674fc674.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6585528 (6.3M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291497/DSC_0540_7e315ca6-a223-46c1-980a-5604674fc674.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.28M  --.-KB/s    in 0.1s
#
# 2024-07-29 15:58:27 (54.5 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291497/DSC_0540_7e315ca6-a223-46c1-980a-5604674fc674.jpg’ saved [6585528/6585528]
#
# --2024-07-29 15:58:27--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291530/DSC_0780_33c97a7d-14ab-4805-babf-8e0e5b993587.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7345614 (7.0M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291530/DSC_0780_33c97a7d-14ab-4805-babf-8e0e5b993587.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   7.00M  --.-KB/s    in 0.1s
#
# 2024-07-29 15:58:28 (56.1 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291530/DSC_0780_33c97a7d-14ab-4805-babf-8e0e5b993587.jpg’ saved [7345614/7345614]
#
# --2024-07-29 15:58:28--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291548/DSC_0154_97c08ee3-7b6f-4d55-be4f-1dd8adf42f5e.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6843830 (6.5M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291548/DSC_0154_97c08ee3-7b6f-4d55-be4f-1dd8adf42f5e.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.53M  --.-KB/s    in 0.1s
#
# 2024-07-29 15:58:28 (48.0 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291548/DSC_0154_97c08ee3-7b6f-4d55-be4f-1dd8adf42f5e.jpg’ saved [6843830/6843830]
#
# --2024-07-29 15:58:28--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291579/DSC_5114_be897ee9-59d2-486a-9fe9-6506cb403a1f.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 12959705 (12M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291579/DSC_5114_be897ee9-59d2-486a-9fe9-6506cb403a1f.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  12.36M  47.2MB/s    in 0.3s
#
# 2024-07-29 15:58:28 (47.2 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291579/DSC_5114_be897ee9-59d2-486a-9fe9-6506cb403a1f.jpg’ saved [12959705/12959705]
#
# --2024-07-29 15:58:28--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291579/DSC_5255_1e41f559-018b-4a39-8b16-ed663cc2cdb0.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 11688049 (11M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291579/DSC_5255_1e41f559-018b-4a39-8b16-ed663cc2cdb0.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  11.15M  20.7MB/s    in 0.5s
#
# 2024-07-29 15:58:29 (20.7 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291579/DSC_5255_1e41f559-018b-4a39-8b16-ed663cc2cdb0.jpg’ saved [11688049/11688049]
#
# --2024-07-29 15:58:29--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291595/DSC_5653_dca72fb1-67df-435b-9c7f-6d014b06b2a1.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13162475 (13M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291595/DSC_5653_dca72fb1-67df-435b-9c7f-6d014b06b2a1.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  12.55M  48.4MB/s    in 0.3s
#
# 2024-07-29 15:58:29 (48.4 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291595/DSC_5653_dca72fb1-67df-435b-9c7f-6d014b06b2a1.jpg’ saved [13162475/13162475]
#
# --2024-07-29 15:58:29--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291595/DSC_5751_af9a7eab-6241-4fe6-8fdd-84a616043eed.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 11464033 (11M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291595/DSC_5751_af9a7eab-6241-4fe6-8fdd-84a616043eed.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  10.93M  42.7MB/s    in 0.3s
#
# 2024-07-29 15:58:30 (42.7 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291595/DSC_5751_af9a7eab-6241-4fe6-8fdd-84a616043eed.jpg’ saved [11464033/11464033]
#
# --2024-07-29 15:58:30--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291605/DSC_0267_6db2a9a9-b6c7-4402-911e-d3fbb4636d12.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6556601 (6.3M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291605/DSC_0267_6db2a9a9-b6c7-4402-911e-d3fbb4636d12.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.25M  --.-KB/s    in 0.1s
#
# 2024-07-29 15:58:30 (51.6 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291605/DSC_0267_6db2a9a9-b6c7-4402-911e-d3fbb4636d12.jpg’ saved [6556601/6556601]
#
# --2024-07-29 15:58:30--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291612/DSC_7125_1524ba81-38df-4a75-89a6-5e50e2314975.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6142616 (5.9M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291612/DSC_7125_1524ba81-38df-4a75-89a6-5e50e2314975.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   5.86M  --.-KB/s    in 0.07s
#
# 2024-07-29 15:58:30 (87.1 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291612/DSC_7125_1524ba81-38df-4a75-89a6-5e50e2314975.jpg’ saved [6142616/6142616]
#
# --2024-07-29 15:58:30--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291642/DSC_2215_285e603f-ed55-413e-89ea-3548fe4e2e73.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6187164 (5.9M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291642/DSC_2215_285e603f-ed55-413e-89ea-3548fe4e2e73.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   5.90M  --.-KB/s    in 0.07s
#
# 2024-07-29 15:58:31 (89.9 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291642/DSC_2215_285e603f-ed55-413e-89ea-3548fe4e2e73.jpg’ saved [6187164/6187164]
#
# --2024-07-29 15:58:31--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291645/DSC_0495_fb86b1fb-16b2-4d97-b0ae-04ed11f083f0.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6687018 (6.4M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291645/DSC_0495_fb86b1fb-16b2-4d97-b0ae-04ed11f083f0.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.38M  --.-KB/s    in 0.02s
#
# 2024-07-29 15:58:31 (288 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291645/DSC_0495_fb86b1fb-16b2-4d97-b0ae-04ed11f083f0.jpg’ saved [6687018/6687018]
#
# --2024-07-29 15:58:31--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291664/DSC_4136_b05c17a1-0637-4ef6-9f86-a75169b34a26.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6450112 (6.2M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291664/DSC_4136_b05c17a1-0637-4ef6-9f86-a75169b34a26.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.15M  --.-KB/s    in 0.1s
#
# 2024-07-29 15:58:31 (53.9 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291664/DSC_4136_b05c17a1-0637-4ef6-9f86-a75169b34a26.jpg’ saved [6450112/6450112]
#
# --2024-07-29 15:58:31--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291665/CAP_3747_964e89c5-2428-4e79-b135-3d3c08d69b02.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 10562512 (10M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291665/CAP_3747_964e89c5-2428-4e79-b135-3d3c08d69b02.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  10.07M  33.7MB/s    in 0.3s
#
# 2024-07-29 15:58:31 (33.7 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291665/CAP_3747_964e89c5-2428-4e79-b135-3d3c08d69b02.jpg’ saved [10562512/10562512]
#
# --2024-07-29 15:58:31--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291669/DSC_0127_68e6008a-956e-417c-95f7-f756bed64c49.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6790029 (6.5M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291669/DSC_0127_68e6008a-956e-417c-95f7-f756bed64c49.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.47M  --.-KB/s    in 0.09s
#
# 2024-07-29 15:58:32 (73.2 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291669/DSC_0127_68e6008a-956e-417c-95f7-f756bed64c49.jpg’ saved [6790029/6790029]
#
# --2024-07-29 15:58:32--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291669/DSC_0293_e8f22b21-8c76-48a0-b9fa-e9383e7717bc.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7028015 (6.7M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291669/DSC_0293_e8f22b21-8c76-48a0-b9fa-e9383e7717bc.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.70M  32.2MB/s    in 0.2s
#
# 2024-07-29 15:58:32 (32.2 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291669/DSC_0293_e8f22b21-8c76-48a0-b9fa-e9383e7717bc.jpg’ saved [7028015/7028015]
#
# --2024-07-29 15:58:32--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291670/DSC_0048_a036b1bf-2b64-4e97-9544-42bf46ab9542.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5995682 (5.7M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291670/DSC_0048_a036b1bf-2b64-4e97-9544-42bf46ab9542.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   5.72M  34.2MB/s    in 0.2s
#
# 2024-07-29 15:58:32 (34.2 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291670/DSC_0048_a036b1bf-2b64-4e97-9544-42bf46ab9542.jpg’ saved [5995682/5995682]
#
# --2024-07-29 15:58:32--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291670/DSC_0057_fbbb9a5b-e4c7-4b74-9a88-58c937d68852.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5648969 (5.4M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291670/DSC_0057_fbbb9a5b-e4c7-4b74-9a88-58c937d68852.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   5.39M  --.-KB/s    in 0.04s
#
# 2024-07-29 15:58:32 (145 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291670/DSC_0057_fbbb9a5b-e4c7-4b74-9a88-58c937d68852.jpg’ saved [5648969/5648969]
#
# --2024-07-29 15:58:32--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291670/DSC_0137_76331532-03c0-436f-933e-878fb201e64b.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6871264 (6.6M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291670/DSC_0137_76331532-03c0-436f-933e-878fb201e64b.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.55M  24.0MB/s    in 0.3s
#
# 2024-07-29 15:58:33 (24.0 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291670/DSC_0137_76331532-03c0-436f-933e-878fb201e64b.jpg’ saved [6871264/6871264]
#
# --2024-07-29 15:58:33--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291506/DSC_0282_20bdd53b-e616-4227-995a-79c83c21b4ea.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7039047 (6.7M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291506/DSC_0282_20bdd53b-e616-4227-995a-79c83c21b4ea.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.71M  --.-KB/s    in 0.07s
#
# 2024-07-29 15:58:33 (94.8 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291506/DSC_0282_20bdd53b-e616-4227-995a-79c83c21b4ea.jpg’ saved [7039047/7039047]
#
# --2024-07-29 15:58:33--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291518/DSC_0847_b739c955-6644-47a6-b6d9-d64406e2cea9.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7172453 (6.8M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291518/DSC_0847_b739c955-6644-47a6-b6d9-d64406e2cea9.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.84M  --.-KB/s    in 0.04s
#
# 2024-07-29 15:58:33 (183 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291518/DSC_0847_b739c955-6644-47a6-b6d9-d64406e2cea9.jpg’ saved [7172453/7172453]
#
# --2024-07-29 15:58:33--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291543/DSC_3140_19b0bb42-b4da-4dcd-8f03-901e90b5e0ef.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6365049 (6.1M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291543/DSC_3140_19b0bb42-b4da-4dcd-8f03-901e90b5e0ef.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.07M  --.-KB/s    in 0.1s
#
# 2024-07-29 15:58:34 (53.2 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291543/DSC_3140_19b0bb42-b4da-4dcd-8f03-901e90b5e0ef.jpg’ saved [6365049/6365049]
#
# --2024-07-29 15:58:34--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291543/DSC_3454_b5116ec2-243d-4054-a016-f41666b385be.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6434863 (6.1M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291543/DSC_3454_b5116ec2-243d-4054-a016-f41666b385be.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.14M  --.-KB/s    in 0.06s
#
# 2024-07-29 15:58:34 (103 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291543/DSC_3454_b5116ec2-243d-4054-a016-f41666b385be.jpg’ saved [6434863/6434863]
#
# --2024-07-29 15:58:34--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291551/DSC_4236_532c629f-bb2e-440f-b691-464533d665db.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6236797 (5.9M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291551/DSC_4236_532c629f-bb2e-440f-b691-464533d665db.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   5.95M  --.-KB/s    in 0.1s
#
# 2024-07-29 15:58:34 (58.4 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291551/DSC_4236_532c629f-bb2e-440f-b691-464533d665db.jpg’ saved [6236797/6236797]
#
# --2024-07-29 15:58:34--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291576/DSC_0208_d32ef29a-9adb-4e13-b6fa-ceede6bc6470.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5771135 (5.5M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291576/DSC_0208_d32ef29a-9adb-4e13-b6fa-ceede6bc6470.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   5.50M  --.-KB/s    in 0.1s
#
# 2024-07-29 15:58:34 (41.6 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291576/DSC_0208_d32ef29a-9adb-4e13-b6fa-ceede6bc6470.jpg’ saved [5771135/5771135]
#
# --2024-07-29 15:58:34--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291576/DSC_0636_c87ce51f-e760-401e-bb79-923f815448f4.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6028916 (5.7M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291576/DSC_0636_c87ce51f-e760-401e-bb79-923f815448f4.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   5.75M  --.-KB/s    in 0.09s
#
# 2024-07-29 15:58:34 (67.2 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291576/DSC_0636_c87ce51f-e760-401e-bb79-923f815448f4.jpg’ saved [6028916/6028916]
#
# --2024-07-29 15:58:34--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3047/291573/DSC_0246_5769acd5-9ce5-4f39-9808-f560d54c96c0.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6128605 (5.8M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3047/291573/DSC_0246_5769acd5-9ce5-4f39-9808-f560d54c96c0.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   5.84M  --.-KB/s    in 0.1s
#
# 2024-07-29 15:58:35 (44.4 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3047/291573/DSC_0246_5769acd5-9ce5-4f39-9808-f560d54c96c0.jpg’ saved [6128605/6128605]
#
# --2024-07-29 15:58:35--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3047/291584/DSC_0364_49233411-5f9c-42e3-9348-df990d5f8a17.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6882477 (6.6M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3047/291584/DSC_0364_49233411-5f9c-42e3-9348-df990d5f8a17.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.56M  --.-KB/s    in 0.1s
#
# 2024-07-29 15:58:35 (47.1 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3047/291584/DSC_0364_49233411-5f9c-42e3-9348-df990d5f8a17.jpg’ saved [6882477/6882477]
#
# --2024-07-29 15:58:35--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/361790/DSC_0008_9ffcc6f4-e247-4272-b9f5-b3710ec6109e.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6539379 (6.2M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/361790/DSC_0008_9ffcc6f4-e247-4272-b9f5-b3710ec6109e.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.24M  30.8MB/s    in 0.2s
#
# 2024-07-29 15:58:35 (30.8 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/361790/DSC_0008_9ffcc6f4-e247-4272-b9f5-b3710ec6109e.jpg’ saved [6539379/6539379]
#
# --2024-07-29 15:58:35--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/443381/SUNAMI(2_a5741f1f-a08e-4a8c-9a53-2b080c9616b9.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6184540 (5.9M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/443381/SUNAMI(2_a5741f1f-a08e-4a8c-9a53-2b080c9616b9.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   5.90M  --.-KB/s    in 0.03s
#
# 2024-07-29 15:58:36 (216 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/443381/SUNAMI(2_a5741f1f-a08e-4a8c-9a53-2b080c9616b9.jpg’ saved [6184540/6184540]
#
# --2024-07-29 15:58:36--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/473477/DSC_5313_4a6bf1ce-fd99-4fe5-88c2-14a71df658fe.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6195400 (5.9M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/473477/DSC_5313_4a6bf1ce-fd99-4fe5-88c2-14a71df658fe.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   5.91M  --.-KB/s    in 0.04s
#
# 2024-07-29 15:58:36 (169 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/473477/DSC_5313_4a6bf1ce-fd99-4fe5-88c2-14a71df658fe.jpg’ saved [6195400/6195400]
#
# --2024-07-29 15:58:36--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/583511/DSC_0048_02a7ccd9-68d8-4205-a4d3-8f82840a45ce.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5650848 (5.4M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/583511/DSC_0048_02a7ccd9-68d8-4205-a4d3-8f82840a45ce.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   5.39M  32.9MB/s    in 0.2s
#
# 2024-07-29 15:58:36 (32.9 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/583511/DSC_0048_02a7ccd9-68d8-4205-a4d3-8f82840a45ce.jpg’ saved [5650848/5650848]
#
# --2024-07-29 15:58:36--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/583511/DSC_0129_f90b76bf-ddda-4cf7-85a0-efd7c326c0ba.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6671863 (6.4M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/583511/DSC_0129_f90b76bf-ddda-4cf7-85a0-efd7c326c0ba.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.36M  --.-KB/s    in 0.02s
#
# 2024-07-29 15:58:36 (277 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/583511/DSC_0129_f90b76bf-ddda-4cf7-85a0-efd7c326c0ba.jpg’ saved [6671863/6671863]
#
# --2024-07-29 15:58:36--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/614389/DSC_0002_710e097e-55db-4ae2-aeac-f7102a9aa790.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6100907 (5.8M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/614389/DSC_0002_710e097e-55db-4ae2-aeac-f7102a9aa790.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   5.82M  27.1MB/s    in 0.2s
#
# 2024-07-29 15:58:37 (27.1 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/614389/DSC_0002_710e097e-55db-4ae2-aeac-f7102a9aa790.jpg’ saved [6100907/6100907]
#
# --2024-07-29 15:58:37--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/614984/DSC_0004_63ea7a2b-0c1a-4929-aae9-48cb77493be8.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4936041 (4.7M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/614984/DSC_0004_63ea7a2b-0c1a-4929-aae9-48cb77493be8.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   4.71M  --.-KB/s    in 0.04s
#
# 2024-07-29 15:58:37 (121 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/614984/DSC_0004_63ea7a2b-0c1a-4929-aae9-48cb77493be8.jpg’ saved [4936041/4936041]
#
# --2024-07-29 15:58:37--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/615474/Dec17201_fab67786-cd87-4ca5-8aac-e064377d43c2.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5308561 (5.1M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/615474/Dec17201_fab67786-cd87-4ca5-8aac-e064377d43c2.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   5.06M  --.-KB/s    in 0.1s
#
# 2024-07-29 15:58:37 (42.4 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/615474/Dec17201_fab67786-cd87-4ca5-8aac-e064377d43c2.jpg’ saved [5308561/5308561]
#
# --2024-07-29 15:58:37--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/616200/DSC_0887_a7d48a01-cffe-4f40-9847-8569c18fdae8.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 8093470 (7.7M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/616200/DSC_0887_a7d48a01-cffe-4f40-9847-8569c18fdae8.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   7.72M  --.-KB/s    in 0.1s
#
# 2024-07-29 15:58:37 (51.5 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/616200/DSC_0887_a7d48a01-cffe-4f40-9847-8569c18fdae8.jpg’ saved [8093470/8093470]
#
# --2024-07-29 15:58:37--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/6064/423324/041_117a21f3-a107-4ab4-ae47-a51c155397a1.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3174113 (3.0M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/6064/423324/041_117a21f3-a107-4ab4-ae47-a51c155397a1.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   3.03M  --.-KB/s    in 0.1s
#
# 2024-07-29 15:58:37 (27.6 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/6064/423324/041_117a21f3-a107-4ab4-ae47-a51c155397a1.jpg’ saved [3174113/3174113]
#
# --2024-07-29 15:58:37--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/7067/533485/DJI_0412_a096554f-4f41-4a6e-92b5-e2882f13fa36.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7181027 (6.8M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/7067/533485/DJI_0412_a096554f-4f41-4a6e-92b5-e2882f13fa36.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.85M  --.-KB/s    in 0.03s
#
# 2024-07-29 15:58:38 (211 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/7067/533485/DJI_0412_a096554f-4f41-4a6e-92b5-e2882f13fa36.jpg’ saved [7181027/7181027]
#
# --2024-07-29 15:58:38--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/7068/615404/DSC_7853_645c74a9-a1f9-490b-91ef-cb152f92d8b2.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 12183780 (12M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/7068/615404/DSC_7853_645c74a9-a1f9-490b-91ef-cb152f92d8b2.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  11.62M  60.1MB/s    in 0.2s
#
# 2024-07-29 15:58:38 (60.1 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/7068/615404/DSC_7853_645c74a9-a1f9-490b-91ef-cb152f92d8b2.jpg’ saved [12183780/12183780]
#
# --2024-07-29 15:58:38--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613531/DSC_0453_7f282688-d51b-48c0-a4cc-3265a4c7401a.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13542919 (13M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613531/DSC_0453_7f282688-d51b-48c0-a4cc-3265a4c7401a.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  12.92M  --.-KB/s    in 0.1s
#
# 2024-07-29 15:58:38 (88.0 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613531/DSC_0453_7f282688-d51b-48c0-a4cc-3265a4c7401a.jpg’ saved [13542919/13542919]
#
# --2024-07-29 15:58:38--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613531/DSC_1295_09068e4d-cbf1-477e-b837-d9d655f82046.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 11481950 (11M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613531/DSC_1295_09068e4d-cbf1-477e-b837-d9d655f82046.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  10.95M  37.7MB/s    in 0.3s
#
# 2024-07-29 15:58:39 (37.7 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613531/DSC_1295_09068e4d-cbf1-477e-b837-d9d655f82046.jpg’ saved [11481950/11481950]
#
# --2024-07-29 15:58:39--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613534/R0001812_ef1b35bd-fdad-4f92-8056-42d16b1a8de0.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6291252 (6.0M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613534/R0001812_ef1b35bd-fdad-4f92-8056-42d16b1a8de0.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.00M  --.-KB/s    in 0.04s
#
# 2024-07-29 15:58:39 (171 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613534/R0001812_ef1b35bd-fdad-4f92-8056-42d16b1a8de0.jpg’ saved [6291252/6291252]
#
# --2024-07-29 15:58:39--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613538/DSC_0885_3c8572e2-7e8a-4049-bb11-9d80d21b93c2.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 15614449 (15M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613538/DSC_0885_3c8572e2-7e8a-4049-bb11-9d80d21b93c2.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  14.89M  78.9MB/s    in 0.2s
#
# 2024-07-29 15:58:39 (78.9 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613538/DSC_0885_3c8572e2-7e8a-4049-bb11-9d80d21b93c2.jpg’ saved [15614449/15614449]
#
# --2024-07-29 15:58:39--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613538/DSC_1043_e5ca2c63-105d-4c92-a1ad-7e8326b8d703.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 14156952 (14M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613538/DSC_1043_e5ca2c63-105d-4c92-a1ad-7e8326b8d703.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  13.50M  44.6MB/s    in 0.3s
#
# 2024-07-29 15:58:40 (44.6 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613538/DSC_1043_e5ca2c63-105d-4c92-a1ad-7e8326b8d703.jpg’ saved [14156952/14156952]
#
# --2024-07-29 15:58:40--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613538/DSC_1428_a693148b-ea81-4605-829b-6fc370465fb3.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 12827683 (12M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613538/DSC_1428_a693148b-ea81-4605-829b-6fc370465fb3.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  12.23M  43.0MB/s    in 0.3s
#
# 2024-07-29 15:58:40 (43.0 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613538/DSC_1428_a693148b-ea81-4605-829b-6fc370465fb3.jpg’ saved [12827683/12827683]
#
# --2024-07-29 15:58:40--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613542/DSC_0554_47c23f20-222a-4c8b-ac94-4224c0886ccc.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 10574820 (10M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613542/DSC_0554_47c23f20-222a-4c8b-ac94-4224c0886ccc.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  10.08M  41.9MB/s    in 0.2s
#
# 2024-07-29 15:58:41 (41.9 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613542/DSC_0554_47c23f20-222a-4c8b-ac94-4224c0886ccc.jpg’ saved [10574820/10574820]
#
# --2024-07-29 15:58:41--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613543/DSC_0140_615c05a5-e11d-445c-a7bd-e95a9a2d8ce3.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 10769993 (10M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613543/DSC_0140_615c05a5-e11d-445c-a7bd-e95a9a2d8ce3.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  10.27M  32.5MB/s    in 0.3s
#
# 2024-07-29 15:58:41 (32.5 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613543/DSC_0140_615c05a5-e11d-445c-a7bd-e95a9a2d8ce3.jpg’ saved [10769993/10769993]
#
# --2024-07-29 15:58:41--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613543/DSC_0460_344bd5f5-1e48-4811-851a-52480f0302f3.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 10590506 (10M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613543/DSC_0460_344bd5f5-1e48-4811-851a-52480f0302f3.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  10.10M  46.4MB/s    in 0.2s
#
# 2024-07-29 15:58:41 (46.4 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613543/DSC_0460_344bd5f5-1e48-4811-851a-52480f0302f3.jpg’ saved [10590506/10590506]
#
# --2024-07-29 15:58:41--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613546/DSC_0398_1bb3657c-f021-4c0f-81c9-8841a60f15d3.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 8941857 (8.5M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613546/DSC_0398_1bb3657c-f021-4c0f-81c9-8841a60f15d3.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   8.53M  47.8MB/s    in 0.2s
#
# 2024-07-29 15:58:42 (47.8 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613546/DSC_0398_1bb3657c-f021-4c0f-81c9-8841a60f15d3.jpg’ saved [8941857/8941857]
#
# --2024-07-29 15:58:42--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613546/DSC_0721_cd6b2ab1-6291-4bf3-b1db-6e6cc7e1f025.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 8144496 (7.8M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613546/DSC_0721_cd6b2ab1-6291-4bf3-b1db-6e6cc7e1f025.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   7.77M  --.-KB/s    in 0.1s
#
# 2024-07-29 15:58:42 (72.3 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613546/DSC_0721_cd6b2ab1-6291-4bf3-b1db-6e6cc7e1f025.jpg’ saved [8144496/8144496]
#
# --2024-07-29 15:58:42--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613546/DSC_0976_cff3a9bc-bdb7-47cc-8c19-fedf79aca3d3.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 9373185 (8.9M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613546/DSC_0976_cff3a9bc-bdb7-47cc-8c19-fedf79aca3d3.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   8.94M  --.-KB/s    in 0.07s
#
# 2024-07-29 15:58:42 (122 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613546/DSC_0976_cff3a9bc-bdb7-47cc-8c19-fedf79aca3d3.jpg’ saved [9373185/9373185]
#
# --2024-07-29 15:58:42--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613547/DSC_0027_831f1237-9ac9-4a7c-81dc-02dd24934fd2.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 9064712 (8.6M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613547/DSC_0027_831f1237-9ac9-4a7c-81dc-02dd24934fd2.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   8.64M  --.-KB/s    in 0.1s
#
# 2024-07-29 15:58:42 (65.4 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613547/DSC_0027_831f1237-9ac9-4a7c-81dc-02dd24934fd2.jpg’ saved [9064712/9064712]
#
# --2024-07-29 15:58:42--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613547/DSC_1534_a6244d9e-2a21-43fb-9451-e96d703ae163.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 9614227 (9.2M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613547/DSC_1534_a6244d9e-2a21-43fb-9451-e96d703ae163.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   9.17M  31.7MB/s    in 0.3s
#
# 2024-07-29 15:58:43 (31.7 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613547/DSC_1534_a6244d9e-2a21-43fb-9451-e96d703ae163.jpg’ saved [9614227/9614227]
#
# --2024-07-29 15:58:43--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613547/DSC_3688_7ebe7e44-1cc4-40e2-8974-6f892b31747c.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 8849928 (8.4M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613547/DSC_3688_7ebe7e44-1cc4-40e2-8974-6f892b31747c.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   8.44M  --.-KB/s    in 0.07s
#
# 2024-07-29 15:58:43 (114 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613547/DSC_3688_7ebe7e44-1cc4-40e2-8974-6f892b31747c.jpg’ saved [8849928/8849928]
#
# --2024-07-29 15:58:43--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613547/DSC_3759_f00710ac-2b3a-4a4f-afdc-d562f0eb776d.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 11129101 (11M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613547/DSC_3759_f00710ac-2b3a-4a4f-afdc-d562f0eb776d.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  10.61M  27.5MB/s    in 0.4s
#
# 2024-07-29 15:58:43 (27.5 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613547/DSC_3759_f00710ac-2b3a-4a4f-afdc-d562f0eb776d.jpg’ saved [11129101/11129101]
#
# --2024-07-29 15:58:43--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613548/DSC_1171_4388f594-1f64-40a8-9ac8-b0709b892b29.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7981894 (7.6M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613548/DSC_1171_4388f594-1f64-40a8-9ac8-b0709b892b29.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   7.61M  --.-KB/s    in 0.02s
#
# 2024-07-29 15:58:44 (363 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613548/DSC_1171_4388f594-1f64-40a8-9ac8-b0709b892b29.jpg’ saved [7981894/7981894]
#
# --2024-07-29 15:58:44--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613548/DSC_2864_c027d32a-34f7-42ef-8726-70f9c57ad8c4.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 9439971 (9.0M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613548/DSC_2864_c027d32a-34f7-42ef-8726-70f9c57ad8c4.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   9.00M  50.9MB/s    in 0.2s
#
# 2024-07-29 15:58:44 (50.9 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613548/DSC_2864_c027d32a-34f7-42ef-8726-70f9c57ad8c4.jpg’ saved [9439971/9439971]
#
# --2024-07-29 15:58:44--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613549/DSC_0437_4ec4c8c7-525f-40a5-a8f3-e53d4b94d0a8.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 12468953 (12M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613549/DSC_0437_4ec4c8c7-525f-40a5-a8f3-e53d4b94d0a8.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  11.89M  28.1MB/s    in 0.4s
#
# 2024-07-29 15:58:45 (28.1 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613549/DSC_0437_4ec4c8c7-525f-40a5-a8f3-e53d4b94d0a8.jpg’ saved [12468953/12468953]
#
# --2024-07-29 15:58:45--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613550/DSC_0437_f85efdd5-33e7-4447-b706-728bda00a0ec.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 12434853 (12M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613550/DSC_0437_f85efdd5-33e7-4447-b706-728bda00a0ec.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  11.86M  --.-KB/s    in 0.1s
#
# 2024-07-29 15:58:45 (80.7 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613550/DSC_0437_f85efdd5-33e7-4447-b706-728bda00a0ec.jpg’ saved [12434853/12434853]
#
# --2024-07-29 15:58:45--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613551/DSC_0972_cee110f9-dd6f-47bf-8e6e-19019daac1e3.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 10884848 (10M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613551/DSC_0972_cee110f9-dd6f-47bf-8e6e-19019daac1e3.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  10.38M  27.5MB/s    in 0.4s
#
# 2024-07-29 15:58:45 (27.5 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613551/DSC_0972_cee110f9-dd6f-47bf-8e6e-19019daac1e3.jpg’ saved [10884848/10884848]
#
# --2024-07-29 15:58:45--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613551/DSC_1379_2515d999-9f7a-460b-8d21-a5797471f4f3.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 8832676 (8.4M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613551/DSC_1379_2515d999-9f7a-460b-8d21-a5797471f4f3.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   8.42M  --.-KB/s    in 0.1s
#
# 2024-07-29 15:58:46 (58.1 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613551/DSC_1379_2515d999-9f7a-460b-8d21-a5797471f4f3.jpg’ saved [8832676/8832676]
#
# --2024-07-29 15:58:46--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613551/DSC_1609_c7872f25-4765-407f-bac2-40b2a3327521.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 8877053 (8.5M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613551/DSC_1609_c7872f25-4765-407f-bac2-40b2a3327521.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   8.46M  41.0MB/s    in 0.2s
#
# 2024-07-29 15:58:46 (41.0 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613551/DSC_1609_c7872f25-4765-407f-bac2-40b2a3327521.jpg’ saved [8877053/8877053]
#
# --2024-07-29 15:58:46--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613555/DSC_0756_6c264510-5724-4dda-b630-b1cf2174a0aa.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13477141 (13M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613555/DSC_0756_6c264510-5724-4dda-b630-b1cf2174a0aa.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  12.85M  25.2MB/s    in 0.5s
#
# 2024-07-29 15:58:47 (25.2 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613555/DSC_0756_6c264510-5724-4dda-b630-b1cf2174a0aa.jpg’ saved [13477141/13477141]
#
# --2024-07-29 15:58:47--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613555/DSC_1064_e22037e6-6694-49a8-973b-30291265db1c.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 11482721 (11M) [image/jpeg]
# ...
# HTTP request sent, awaiting response... 200 OK
# Length: 6183805 (5.9M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615125/MarkBail_94f99631-5c85-4e76-a0eb-5928c272686c.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   5.90M  33.3MB/s    in 0.2s
#
# 2024-07-29 16:00:14 (33.3 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615125/MarkBail_94f99631-5c85-4e76-a0eb-5928c272686c.jpg’ saved [6183805/6183805]
#
# --2024-07-29 16:00:14--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615126/SteveBla_5aff1596-f896-4fa7-896d-b08829047fbf.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3502106 (3.3M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615126/SteveBla_5aff1596-f896-4fa7-896d-b08829047fbf.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   3.34M  19.0MB/s    in 0.2s
#
# 2024-07-29 16:00:15 (19.0 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615126/SteveBla_5aff1596-f896-4fa7-896d-b08829047fbf.jpg’ saved [3502106/3502106]
#
# --2024-07-29 16:00:15--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615126/SteveBla_b44e7a3e-d97e-4d03-88aa-113b34a138d0.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3489221 (3.3M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615126/SteveBla_b44e7a3e-d97e-4d03-88aa-113b34a138d0.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   3.33M  --.-KB/s    in 0.009s
#
# 2024-07-29 16:00:15 (362 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615126/SteveBla_b44e7a3e-d97e-4d03-88aa-113b34a138d0.jpg’ saved [3489221/3489221]
#
# --2024-07-29 16:00:15--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615129/BrettGro_446a6039-6d53-41ad-9979-a908c693107b.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3470360 (3.3M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615129/BrettGro_446a6039-6d53-41ad-9979-a908c693107b.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   3.31M  --.-KB/s    in 0.01s
#
# 2024-07-29 16:00:15 (300 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615129/BrettGro_446a6039-6d53-41ad-9979-a908c693107b.jpg’ saved [3470360/3470360]
#
# --2024-07-29 16:00:15--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615129/BrettGro_48db0db6-2446-4c54-823d-89dd753d308a.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3499553 (3.3M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615129/BrettGro_48db0db6-2446-4c54-823d-89dd753d308a.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   3.34M  11.6MB/s    in 0.3s
#
# 2024-07-29 16:00:16 (11.6 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615129/BrettGro_48db0db6-2446-4c54-823d-89dd753d308a.jpg’ saved [3499553/3499553]
#
# --2024-07-29 16:00:16--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615130/DonBarre_fea9ac22-2156-4895-b1bb-e1f3a83bb6a0.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6148655 (5.9M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615130/DonBarre_fea9ac22-2156-4895-b1bb-e1f3a83bb6a0.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   5.86M  26.3MB/s    in 0.2s
#
# 2024-07-29 16:00:16 (26.3 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615130/DonBarre_fea9ac22-2156-4895-b1bb-e1f3a83bb6a0.jpg’ saved [6148655/6148655]
#
# --2024-07-29 16:00:16--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615152/19-1-352_1ce69a0e-806a-468d-ac36-805b60a74b7d.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 10119686 (9.7M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615152/19-1-352_1ce69a0e-806a-468d-ac36-805b60a74b7d.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   9.65M  47.7MB/s    in 0.2s
#
# 2024-07-29 16:00:16 (47.7 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615152/19-1-352_1ce69a0e-806a-468d-ac36-805b60a74b7d.jpg’ saved [10119686/10119686]
#
# --2024-07-29 16:00:16--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615152/19-1-352_30124d91-cccf-4d20-b7aa-d462fd33762c.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7521399 (7.2M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615152/19-1-352_30124d91-cccf-4d20-b7aa-d462fd33762c.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   7.17M  37.6MB/s    in 0.2s
#
# 2024-07-29 16:00:17 (37.6 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615152/19-1-352_30124d91-cccf-4d20-b7aa-d462fd33762c.jpg’ saved [7521399/7521399]
#
# --2024-07-29 16:00:17--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615165/DSC_4349_71c2c8e2-02c7-49fa-8360-5a29681a6a66.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 14878320 (14M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615165/DSC_4349_71c2c8e2-02c7-49fa-8360-5a29681a6a66.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  14.19M  --.-KB/s    in 0.1s
#
# 2024-07-29 16:00:17 (110 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615165/DSC_4349_71c2c8e2-02c7-49fa-8360-5a29681a6a66.jpg’ saved [14878320/14878320]
#
# --2024-07-29 16:00:17--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615185/DSC_4222_a9fa1552-85c5-4545-9385-b47f711d42fc.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 9243329 (8.8M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615185/DSC_4222_a9fa1552-85c5-4545-9385-b47f711d42fc.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   8.81M  36.4MB/s    in 0.2s
#
# 2024-07-29 16:00:17 (36.4 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615185/DSC_4222_a9fa1552-85c5-4545-9385-b47f711d42fc.jpg’ saved [9243329/9243329]
#
# --2024-07-29 16:00:17--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615185/DSC_4271_eccb7fa5-fcab-4831-b054-89c6492fc265.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7666520 (7.3M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615185/DSC_4271_eccb7fa5-fcab-4831-b054-89c6492fc265.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   7.31M  --.-KB/s    in 0.06s
#
# 2024-07-29 16:00:17 (122 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615185/DSC_4271_eccb7fa5-fcab-4831-b054-89c6492fc265.jpg’ saved [7666520/7666520]
#
# --2024-07-29 16:00:17--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615192/-031_9834a71a-20b5-4ecd-9b7c-9df27bf422be.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 14010771 (13M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615192/-031_9834a71a-20b5-4ecd-9b7c-9df27bf422be.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  13.36M  24.3MB/s    in 0.5s
#
# 2024-07-29 16:00:18 (24.3 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615192/-031_9834a71a-20b5-4ecd-9b7c-9df27bf422be.jpg’ saved [14010771/14010771]
#
# --2024-07-29 16:00:18--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615196/DSC_0044_b1e5f34e-1078-4eef-8cf5-6c7547cda1f1.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6441710 (6.1M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615196/DSC_0044_b1e5f34e-1078-4eef-8cf5-6c7547cda1f1.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.14M  --.-KB/s    in 0.1s
#
# 2024-07-29 16:00:18 (51.5 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615196/DSC_0044_b1e5f34e-1078-4eef-8cf5-6c7547cda1f1.jpg’ saved [6441710/6441710]
#
# --2024-07-29 16:00:18--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615198/AAD_0595_86704645-da20-44be-96b6-5ad39fad6ced.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 8381787 (8.0M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615198/AAD_0595_86704645-da20-44be-96b6-5ad39fad6ced.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   7.99M  44.7MB/s    in 0.2s
#
# 2024-07-29 16:00:19 (44.7 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615198/AAD_0595_86704645-da20-44be-96b6-5ad39fad6ced.jpg’ saved [8381787/8381787]
#
# --2024-07-29 16:00:19--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615216/DSC_0340_8a867306-11d5-45ec-ab39-686318d37d6d.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3108570 (3.0M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615216/DSC_0340_8a867306-11d5-45ec-ab39-686318d37d6d.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   2.96M  17.0MB/s    in 0.2s
#
# 2024-07-29 16:00:19 (17.0 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615216/DSC_0340_8a867306-11d5-45ec-ab39-686318d37d6d.jpg’ saved [3108570/3108570]
#
# --2024-07-29 16:00:19--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615229/DSC_4997_5f2cda4a-a481-45be-8e34-7e00391a60cd.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13105600 (12M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615229/DSC_4997_5f2cda4a-a481-45be-8e34-7e00391a60cd.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  12.50M  40.1MB/s    in 0.3s
#
# 2024-07-29 16:00:19 (40.1 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615229/DSC_4997_5f2cda4a-a481-45be-8e34-7e00391a60cd.jpg’ saved [13105600/13105600]
#
# --2024-07-29 16:00:19--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615236/DSC_5703_7ae5d7fc-4129-442b-ac3f-0e92f643aea1.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 14166884 (14M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615236/DSC_5703_7ae5d7fc-4129-442b-ac3f-0e92f643aea1.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  13.51M  32.6MB/s    in 0.4s
#
# 2024-07-29 16:00:20 (32.6 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615236/DSC_5703_7ae5d7fc-4129-442b-ac3f-0e92f643aea1.jpg’ saved [14166884/14166884]
#
# --2024-07-29 16:00:20--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9107/616210/DSC_0605_3bc8f783-0a98-4937-9a1d-0683157bf7aa.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 14269264 (14M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9107/616210/DSC_0605_3bc8f783-0a98-4937-9a1d-0683157bf7aa.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  13.61M  34.9MB/s    in 0.4s
#
# 2024-07-29 16:00:20 (34.9 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9107/616210/DSC_0605_3bc8f783-0a98-4937-9a1d-0683157bf7aa.jpg’ saved [14269264/14269264]
#
# --2024-07-29 16:00:20--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9107/616212/DSC_8434_0a00aaa2-c852-4ad5-9c80-21ec2ec18375.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 9037086 (8.6M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9107/616212/DSC_8434_0a00aaa2-c852-4ad5-9c80-21ec2ec18375.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   8.62M  --.-KB/s    in 0.1s
#
# 2024-07-29 16:00:21 (63.2 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9107/616212/DSC_8434_0a00aaa2-c852-4ad5-9c80-21ec2ec18375.jpg’ saved [9037086/9037086]
#
# --2024-07-29 16:00:21--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9107/616213/DSC_0171_581355d1-1a23-4d4d-be16-f653e15ce249.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5219168 (5.0M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9107/616213/DSC_0171_581355d1-1a23-4d4d-be16-f653e15ce249.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   4.98M  --.-KB/s    in 0.05s
#
# 2024-07-29 16:00:21 (94.5 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9107/616213/DSC_0171_581355d1-1a23-4d4d-be16-f653e15ce249.jpg’ saved [5219168/5219168]
#
# --2024-07-29 16:00:21--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9113/615622/DSC_0472_cd72d5c5-3c42-4c3c-8fe0-d25222155f02.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 11267786 (11M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9113/615622/DSC_0472_cd72d5c5-3c42-4c3c-8fe0-d25222155f02.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  10.75M  25.7MB/s    in 0.4s
#
# 2024-07-29 16:00:21 (25.7 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9113/615622/DSC_0472_cd72d5c5-3c42-4c3c-8fe0-d25222155f02.jpg’ saved [11267786/11267786]
#
# --2024-07-29 16:00:21--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9157/616220/DSC_7783_2e13e2d6-a09c-4106-9301-8f72d349deb3.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 11943248 (11M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9157/616220/DSC_7783_2e13e2d6-a09c-4106-9301-8f72d349deb3.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  11.39M  25.3MB/s    in 0.5s
#
# 2024-07-29 16:00:22 (25.3 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9157/616220/DSC_7783_2e13e2d6-a09c-4106-9301-8f72d349deb3.jpg’ saved [11943248/11943248]
#
# --2024-07-29 16:00:22--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9157/616220/DSC_7980_a72ca46c-fd46-48e4-84d1-f4bd1a07c34c.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 14128685 (13M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9157/616220/DSC_7980_a72ca46c-fd46-48e4-84d1-f4bd1a07c34c.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  13.47M  49.9MB/s    in 0.3s
#
# 2024-07-29 16:00:22 (49.9 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9157/616220/DSC_7980_a72ca46c-fd46-48e4-84d1-f4bd1a07c34c.jpg’ saved [14128685/14128685]
#
# --2024-07-29 16:00:22--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9161/616221/FEMA_REG_f18629c3-2837-4e84-9cfa-6b3575fd9b90.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5441584 (5.2M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9161/616221/FEMA_REG_f18629c3-2837-4e84-9cfa-6b3575fd9b90.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   5.19M  20.4MB/s    in 0.3s
#
# 2024-07-29 16:00:23 (20.4 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9161/616221/FEMA_REG_f18629c3-2837-4e84-9cfa-6b3575fd9b90.jpg’ saved [5441584/5441584]
#
# FINISHED --2024-07-29 16:00:23--
# Total wall clock time: 1m 59s
# Downloaded: 397 files, 3.1G in 1m 4s (49.4 MB/s)
